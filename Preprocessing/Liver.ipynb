# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/indian_liver_patient - indian_liver_patient.csv')

# %% [markdown]
# UNDERSTANDING THE DATASET

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female             0.70              0.10                   187
# 1     62    Male            10.90              5.50                   699
# 2     62    Male             7.30              4.10                   490
# 3     58    Male             1.00              0.40                   182
# 4     72    Male             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male             0.50              0.10                   500
# 579   40    Male             0.60              0.10                    98
# 580   52    Male             0.80              0.20                   245
# 581   31    Male             1.30              0.50                   184
# 582   38    Male             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.describe()
# Out:
#          Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count 583.00           583.00            583.00                583.00
# mean   44.75             3.30              1.49                290.58
# std    16.19             6.21              2.81                242.94
# min     4.00             0.40              0.10                 63.00
# 25%    33.00             0.80              0.20                175.50
# 50%    45.00             1.00              0.30                208.00
# 75%    58.00             2.60              1.30                298.00
# max    90.00            75.00             19.70               2110.00
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                    583.00                      583.00          583.00
# mean                      80.71                      109.91            6.48
# std                      182.62                      288.92            1.09
# ...

# %% [markdown]
# CHECKING AND HANDLING NULL VALUES

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df['Albumin_and_Globulin_Ratio']=df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].mean())

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %% [markdown]
# HANDLING DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ENCODING CATEGORICAL COLUMN

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender']=df['Gender'].map({'Female':0,'Male':1})

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0             0.70              0.10                   187
# 1     62       1            10.90              5.50                   699
# 2     62       1             7.30              4.10                   490
# 3     58       1             1.00              0.40                   182
# 4     72       1             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       1             0.50              0.10                   500
# 579   40       1             0.60              0.10                    98
# 580   52       1             0.80              0.20                   245
# 581   31       1             1.30              0.50                   184
# 582   38       1             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %% [markdown]
# CHANGING THE TARGET COLUMN VALUE FROM 1 AND 2 TO 0 AND 1

# %%
df['Dataset']=df['Dataset'].map({1:0,2:1})

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0             0.70              0.10                   187
# 1     62       1            10.90              5.50                   699
# 2     62       1             7.30              4.10                   490
# 3     58       1             1.00              0.40                   182
# 4     72       1             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60       1             0.50              0.10                   500
# 579   40       1             0.60              0.10                    98
# 580   52       1             0.80              0.20                   245
# 581   31       1             1.30              0.50                   184
# 582   38       1             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %% [markdown]
# CHECK THE DISTRIBUTION OF TARGET COLUMN

# %%
df['Dataset'].value_counts()
# Out:
# Dataset
# 0    406
# 1    164
# Name: count, dtype: int64

# %% [markdown]
# RESAMPLING THE TARGET COLUMNS

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
sample=SMOTE()
x,y=sample.fit_resample(df.drop('Dataset',axis=1),df['Dataset'])

# %%
y.value_counts()
# Out:
# Dataset
# 0    406
# 1    406
# Name: count, dtype: int64

# %% [markdown]
# SPLITTING THE DATA INTO TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        82
#            1       0.82      0.93      0.87        81
#
#     accuracy                           0.87       163
#    macro avg       0.87      0.87      0.86       163
# weighted avg       0.87      0.87      0.86       163

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy')
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", cv_scores.mean())
print("Standard deviation:", cv_scores.std())
# Out:
# Cross-validation scores: [0.76153846 0.7        0.8        0.77692308 0.76744186]
# Mean accuracy: 0.7611806797853309
# Standard deviation: 0.03327812693002576

# %%
pip install xgboost

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier()
xgb_clf.fit(x_train, y_train)
y_pred = xgb_clf.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        82
#            1       0.81      0.84      0.82        81
#
#     accuracy                           0.82       163
#    macro avg       0.82      0.82      0.82       163
# weighted avg       0.82      0.82      0.82       163

# %% [markdown]
# WE WILL CHOOSE EXTRA TREE CLASSIFIER AS IT PRODUCES BETTER ACCURACY

# %% [markdown]
# CONVERTING THE MODEL TO PICKLE FILE

# %%
import pickle
with open('lvr_model.pkl','wb') as f:
  pickle.dump(model,f)
